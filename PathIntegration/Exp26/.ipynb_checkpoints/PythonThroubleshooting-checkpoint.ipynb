# %%
import h5py
import os
import matplotlib.pyplot as plt

# %%
path = os.getcwd()
data = h5py.File(path + '\\20200807_w+,w;Gr43aLexA,+;LexAOpChrTdt,+\\ball\\hdf5_inbound_outbound_Closed_Loop_X_Closed_Loop_Y_20200807_163746_sid_0_tid_1000001.hdf5', 'r')

# %%
#what are the variables it contains?
list(data.keys())
# Out:
# ['frame',
#  'goal heading',
#  'heading',
#  'intx',
#  'inty',
#  'new goal heading',
#  'open loop',
#  'open loop value',
#  'open loop value x',
#  'open loop x',
#  'panel heading',
#  'panel jump',
#  'panel x',
#  'posx',
#  'posy',
#  'pulse_on',
#  'time',
#  'velx',
#  'vely']

# %%
open_loop = data['open loop value']
plt.plot(open_loop)
